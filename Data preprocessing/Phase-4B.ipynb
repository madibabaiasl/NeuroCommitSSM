# %%
# Out:
# [Phase4.5 QC v4.4] manifest=manifest_v3.csv col='file' N=2487
# [Phase4.5 QC v4.4] cache_suffix='auto' (auto-detect=True), require_et=False
# [Phase4.5 QC v4.4] QC config snapshot -> /home/tsultan1/IROS/Data/_dataset_icml_v1/qc_summary_v4.cfg.json
# [ok] QC summary -> /home/tsultan1/IROS/Data/_dataset_icml_v1/qc_summary_v4.csv (N=2487)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3917079/4033751882.py in <module>
#     689     cfg["require_et"] = bool(args.require_et)
#     690
# --> 691     run_qc(
#     692         manifest_csv=Path(args.manifest),
#     693         cache_suffix=str(args.cache_suffix),
#
# /tmp/ipykernel_3917079/4033751882.py in run_qc(manifest_csv, cache_suffix, out_csv, out_by_subject, cfg_snapshot, allow_pass, allow_passwarn, exclusions_csv, allow_core_ok, allow_tri_good, cfg, limit_files)
#     590     if "subject_id" in df.columns:
# ...
